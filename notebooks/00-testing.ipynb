# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys,os
import pandas as pd
import numpy as np
import yaml
import logging

from diana_utils.config.settings import PostgresSettings
from diana_utils.postgres.client import PostgreSQLClient
from diana_utils.utils.file_handler import read_yaml, read_sql_file

pg_settings = PostgresSettings()
logging.basicConfig(level=logging.INFO)

pg_client = PostgreSQLClient(**pg_settings.postgres.model_dump())

logger = logging.getLogger(__name__)

logger.info("setup completed")
# Out:
# INFO:__main__:setup completed

# %%
tst_q = read_sql_file(r'../sql/base_queries.sql')
tst_q
# Out:
# 'SELECT *\n    FROM dm.fact_lxp_training_attendance_vw \n    LIMIT 1000;'

# %% [markdown]
# ## Loading

# %%
with pg_client:
    df = pg_client.read(tst_q)

df.head(5)
# Out:
# INFO:diana_utils.postgres.client:Connection opened: PostgreSQLClient(pid=1073881550)(postgresql://tableau:***@dana-redshift-test.cfbhdvetl7wb.eu-west-1.redshift.amazonaws.com:5439/test)
# INFO:diana_utils.postgres.client:Close connection: PostgreSQLClient(pid=1073881550)(postgresql://tableau:***@dana-redshift-test.cfbhdvetl7wb.eu-west-1.redshift.amazonaws.com:5439/test)
#                             dim_lxp_user_hk  \
# 0  32e9c2a4409bf62d17c0322ad84ade89b664a25b
# 1  e2d5632e948e36eeda62b2d8b99ce219eabba722
# 2  d4a4668ad959f6f1861b807c026c8b7ea4de902a
# 3  97d9cb9cd79a9d18fdb7d492fdb41d444876b724
# 4  25f84891fbc2dd38b4c3aee397c3c84ff2a7415c
#
#                                 lxp_user_hk  \
# 0  df641ad15465af065b646ef3962ac592e8e1fd0e
# 1  5b90d2ab3eb27360cbbc194aaa6231bfe09ecf7f
# 2  e43e54f8c8586ed84f9aae4f58b5be9cecd98e22
# 3  545de2d36ba9113382330a4faf5cadc2d8d7e690
# 4  6c1261397663fed5cf9ce7110863fc76de5e1b46
#
#                         dim_lxp_training_hk  \
# 0  e2cb4e6fa083eaa2d4afcc38f310a3983177d1bb
# 1  f24f6d326bab0fb5ee8cba544a3d0975cdc83022
# 2  2ce9be398f6c8810f6f52da47dc86a7a5ee2a6b4
# 3  5818ca7acabed4e53ef22940da0a127845153c86
# 4  527aa0da57e6859dc50d7d6c1a1661342af9d7fb
#
#                          dim_lxp_session_hk  \
# 0  e2c4f3455b2ddb4aaca1ccefac16ab7b27fa80f1
# 1  a2c9b0f6bc0a21dac6fd249364fda2463d98339e
# 2  657d2e4a0b480c49deea8320e9c2b316b66e8b70
# 3  2704027d4022ee9c85a71ae4d7f18703caf91fc5
# 4  a9c9fdce7bb879c03391d4a1324d49c3d5f4f14b
#
#                              lxp_session_hk             lxp_session_bk  \
# 0  1bbb6fcb0a3d4954eb836128f391e97ed5f3b65e  47644673;;TrainingSession
# 1  396216e53261b1fe47f032ec4218debb983ac23e   6031641;;TrainingSession
# 2  13d2932bbbf99a4a25b7cb56fc4b7d59e31e576d   6052892;;TrainingSession
# 3  889e049c1dec55c427850f80d68fa9302400ccf8   6060097;;TrainingSession
# 4  ee6a7d2248ecd14c034a5c333332dd04e56b6acd   6058681;;TrainingSession
#
#   dim_lxp_meeting_session_hk lxp_meeting_session_hk lxp_meeting_session_bk  \
# 0                       None                   None                   None
# 1                       None                   None                   None
# 2                       None                   None                   None
# 3                       None                   None                   None
# 4                       None                   None                   None
#
#                dim_lxp_training_provider_hk  ... training_learningmode  \
# 0  afebd68686f9497e85d4e730fdf7659fba2aa1e2  ...             ELearning
# 1  d8c3b79aac034a027f65a5a809c1b16a6774f60f  ...          VirtualClass
# 2  7bd881a3cc93ee053e2646bfef2f7f86d082dc20  ...            Presential
# 3  afebd68686f9497e85d4e730fdf7659fba2aa1e2  ...            Presential
# 4  afebd68686f9497e85d4e730fdf7659fba2aa1e2  ...            Presential
#
#   session_learningmode meetingsession_meetingmode lmsaccesscount lmstimespend  \
# 0            ELearning                       None         3.0000      48.6662
# 1         VirtualClass                       None           None         None
# 2         VirtualClass                       None           None         None
# 3           Presential                       None           None         None
# 4           Presential                       None           None         None
#
#   lmsprogresspercent calculated_time            attendance_date content_hub  \
# 0           100.0000         1.00000 2025-04-10 09:13:06.573701       False
# 1           100.0000         0.75000 2021-03-04 01:00:00.000000       False
# 2           100.0000         3.50000 2024-04-23 02:00:00.000000       False
# 3           100.0000         8.50000 2024-05-30 02:00:00.000000       False
# 4           100.0000         7.50000 2022-06-28 02:00:00.000000       False
#
#    training_provider_name
# 0                   OPFOR
# 1  Médecin sans frontière
# 2        Quality Training
# 3                   OPFOR
# 4                   OPFOR
#
# [5 rows x 34 columns]
