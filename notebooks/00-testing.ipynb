# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys,os
import pandas as pd
import numpy as np
import yaml
import logging

from diana_utils.config.settings import PostgresSettings
from diana_utils.postgres.client import PostgreSQLClient
from diana_utils.utils.file_handler import read_yaml, read_sql_file

pg_settings = PostgresSettings()
logging.basicConfig(level=logging.INFO)

pg_client = PostgreSQLClient(**pg_settings.postgres.model_dump())

logger = logging.getLogger(__name__)

logger.info("setup completed")
# Out:
# INFO:__main__:setup completed

# %%
tst_q = read_sql_file(r'../sql/querry.sql')
tst_q
# Out:
# 'SELECT is_tit_ao\nFROM bv.customer_analytical_record_all_latest\nLIMIT 100;'

# %%
with pg_client:
        pass
# Out:
# INFO:diana_utils.postgres.client:Connection opened: PostgreSQLClient(pid=1073767190)(postgresql://tableau:***@dana-redshift-test.cfbhdvetl7wb.eu-west-1.redshift.amazonaws.com:5439/test)
# INFO:diana_utils.postgres.client:Close connection: PostgreSQLClient(pid=1073767190)(postgresql://tableau:***@dana-redshift-test.cfbhdvetl7wb.eu-west-1.redshift.amazonaws.com:5439/test)

# %% [markdown]
# ## Loading

# %%
with pg_client:
    df = pg_client.read(tst_q)

df.head(5)
# Out:
# INFO:diana_utils.postgres.client:Connection opened: PostgreSQLClient(pid=1073808130)(postgresql://tableau:***@dana-redshift-test.cfbhdvetl7wb.eu-west-1.redshift.amazonaws.com:5439/test)
# INFO:diana_utils.postgres.client:Close connection: PostgreSQLClient(pid=1073808130)(postgresql://tableau:***@dana-redshift-test.cfbhdvetl7wb.eu-west-1.redshift.amazonaws.com:5439/test)
#    is_tit_ao
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1
